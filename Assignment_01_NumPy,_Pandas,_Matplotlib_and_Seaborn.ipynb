# %% [markdown]
# # ASSIGNMENT #01

# %% [markdown]
# #####importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###1. Reading the iris dataset to the python environment.

# %%
dataset_name = '/content/iris.xls'
df = pd.read_excel(dataset_name)
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #####to display the first 5 rows

# %%
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# #####displays the rows and columns of the iris dataframe

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# #####to display the last 5 rows

# %%
df.tail()
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# #####to display a series with the datatype of each column in df

# %%
df.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %% [markdown]
# ##### displays the unique values in the classification column

# %%
df['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# #####to display the statistics about the data

# %%
df.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# #####to display summary of df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ###2. Display the columns in the dataset.

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ###3. Calculate the mean of each column of the dataset.

# %%
df.mean()
# Out:
# <ipython-input-13-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# We can't find the mean of the last column as it is a categorical data.

# %% [markdown]
# ###4. Check for the null values present in the dataset.

# %%
null_values = df.isna()
null_values
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
null_values.sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# Therefore there are no null values present in the iris dataset.

# %% [markdown]
# ###5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# ####a.Ploting classification based on SL

# %%
plt.scatter(df['Classification'],df['SL'])
plt.title('On the basis of SL' ,fontsize= 15)
plt.xlabel('Classification',fontsize =12)
plt.ylabel('SL', fontsize = 12)
# Out:
# Text(0, 0.5, 'SL')

# %% [markdown]
# iris-virginica has the largest SL and iris-setosa has the lowest.

# %% [markdown]
# ###b.Classification of the three species using SL and SW

# %%
sns.scatterplot(x = 'SW', y = 'SL', hue = 'Classification', data = df,
                    palette = ['b', 'r', 'g'])
plt.title('CLASSIFICATION on SW & SL')
# Out:
# Text(0.5, 1.0, 'CLASSIFICATION on SW & SL')

# %% [markdown]
# iris-setosa has the highest SW and lowest SL,
# iris-versicolor has almost average value for both SW and SL,
# iris-virginica is having the heighest SL.

# %% [markdown]
# ### c. Ploting classification based on PL

# %%
plt.scatter(df['Classification'],df['PL'],c='brown',marker='^')
plt.title('On the basis of PL' ,fontsize= 18,c='brown')
plt.xlabel('Classification',fontsize =15,c='brown')
plt.xticks(fontsize=10)
plt.ylabel('PL', fontsize = 15,c='brown')
# Out:
# Text(0, 0.5, 'PL')

# %% [markdown]
# iris-virginica has the largest PL while iris-setosa has the lowest.

# %% [markdown]
# ### d.Corelation between SW,SL,PL,PW

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000

# %%
col=df[['SL','SW','PL','PW']]
sns.heatmap(col.corr(), cmap= 'coolwarm',annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Higher intensity of the color red represents higher corelation while the color blue represents negative corelation and the lighter color represnts slight correation.

# %% [markdown]
# ###e. Classification on account of PW

# %%
plt.scatter(df['Classification'],df['PW'],c='brown',marker='^')
plt.title('On the basis of PW' ,fontsize= 18,c='brown')
plt.xlabel('Classification',fontsize =15,c='brown')
plt.xticks(fontsize=10)
plt.ylabel('PW', fontsize = 15,c='brown')
# Out:
# Text(0, 0.5, 'PW')

# %% [markdown]
# iris-virginica: highest,
# iris-versicolor: average,
# iris-setosa: lowest

# %% [markdown]
# ###f.Classification on account of SW

# %%
plt.scatter(df['Classification'],df['SW'])
plt.title('On the basis of SW' ,fontsize= 15)
plt.xlabel('Classification',fontsize =12)
plt.ylabel('SW', fontsize = 12)
# Out:
# Text(0, 0.5, 'SW')

# %% [markdown]
#  iris-setosa has the higest SW

# %% [markdown]
# ####Plotting all the attributes based on classification

# %%
sns.pairplot(df,hue ='Classification')
